# %% [markdown]
# chapter 2 functions - overview
#
#  functions are also objects
#
#  1. built in functions
#  ex- print() etc.
#
#  (1) Input/built in functions-
#  ex- name = input("Enter your name")
#  print("welcome",name)

# %% [markdown]
# chapter 2 functions - overview
#
#  functions are also objects
#
#  1. built in functions
#  ex- print() etc.
#
#  (1) Input/built in functions-
#  ex- name = input("Enter your name")
#  print("welcome",name)

# %%
name = input("Enter your name: ")
print("welcome",name)
age = input("Enter your age: ")
print("you are",age,"years old")
# Out:
# welcome Bhavishya Bhatt
# you are 17 years old

# %%
name = input("Enter your name:")
age = input("Enter your age:")
print(name,"you are",age,"years old")
# Out:
# Bhavishya you are 17 years old

# %% [markdown]
# (2) eval() Function

# %%
# Cell explanation: This example follows the Built-in Functions topic shown in the image above.
 #Explanation: Prompts the user and stores the text returned by input(); numeric text must be converted before arithmetic.
result = eval(input("Enter a simple expression: "))
print(type(result))
print(result)expression = input("Enter a simple expression: ")
 #Explanation: Evaluates the entered expression and stores its computed result; only trusted input should be passed to eval().
 print(type(expression))
 result = eval(expression)

 result = eval(input("Enter a simple expression: "))
 #Explanation: Displays the supplied value or message.
 print(result)
# Out:
#   Cell In[7], line 5
#     print(result)expression = input("Enter a simple expression: ")
#                  ^
# SyntaxError: invalid syntax
