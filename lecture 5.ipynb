# %%
a = 22
b = 7
print(type(a/b))
print(a/b)
print(int(a/b))
print(type(int(a/b)))
# Out:
# <class 'float'>
# 3.142857142857143
# 3
# <class 'int'>

# %%
#Q- how many boxes of capacity 5 items aree required to fill 17 items / 6-15 marks 
items = 17
box_size = 5
boxes_required = items // box_size
if items % box_size != 0:
    boxes_required += 1
print(boxes_required)
# Out:
# 4

# %%
# Q- can we completely fill box pf capacity 5 items with 17 items / 6-15 marks
items = 17 
box_size = 5

 full_boxes = items // box_size

# %%
# find number of boxes used
items = 17
box_size = 5

full_boxes = items // box_size 
remainder = items % box_size 
if remainder <5 :
    print("number of boxes",full_boxes + 1)
# Out:
# number of boxes 4
