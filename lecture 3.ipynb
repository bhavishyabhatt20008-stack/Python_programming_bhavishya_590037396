# %%
print("python began in 1989")
print("python 3 is a modern language")
# Out:
# python began in 1989
# python 3 is a modern language

# %%
a = 300
b = 200
print("price of apples is ", a)
print("price of oranges is",b)
type(a)
print(a+b)
# Out:
# price of apples is  300
# price of oranges is 200
# 500

# %%
a = 84
b =220
print(a/b*100)
# Out:
# 38.18181818181819

# %%
name = "Asha"
score = 88
print(f"{name} scored {score} marks")
# Out:
# Asha scored 88 marks

# %%
value = 10 
print(type(value))




print(type(3.5))
print(type(True))
print(type("Hello"))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>

# %%
a = 10
b = 10.0
print(a == b)
print(type(a))
print(type(b))
# Out:
# True
# <class 'int'>
# <class 'float'>

# %%
a = 10
b = 10.0
print(a == b)
print(type("a"))
print(type("b"))
# Out:
# True
# <class 'str'>
# <class 'str'>
